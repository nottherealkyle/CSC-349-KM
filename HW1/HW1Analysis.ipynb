# %% [markdown]
# <a href="https://colab.research.google.com/github/nottherealkyle/CSC-349-KM/blob/main/HW1/HW1Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Analysis:
#
#
# 1.   Q: Based on the instructional videos, what are the key steps for managing files between Google Colab and GitHub?
#
#      A:The key steps for managing files between GitHub and Google Colab are to first create your Colab notbook (.ipynb) file, then after finishing its content, you must upload it to the proper github folder by either saving the notebook and uploading it to the repository or saving a copy of the file into the repository.
#
#
# 2.   Q: Did all Module 0 notebooks execute successfully in Colab on the first try, or did you need to adjust any syntax or dependencies?
#
#      A: All of my notebooks executed successfully with no errors.
#
# 3.   Q:Explain how you created your repository and organized your files (whether using VS Code or the GitHub web interface).
#
#      A: I created my repository by clicking on my profile, going to "repositories", clicking "create new repository", and naming it CSC-349-KM and making it public. I structured my repository to have folders name "HWX" for each homework, and putting the nessecary Colab notebooks within them for each homework.
#
# 4.   Q:Why is establishing a strong command of basic Python data structures and syntax critical before moving on to core machine learning algorithms?
#
#      A: Establishing a strong command of basic Python data structure and syntax is critical because machine learning algorithims and AI models in general are built using Python, and utilize the data structures present within Python to a complex degree.
